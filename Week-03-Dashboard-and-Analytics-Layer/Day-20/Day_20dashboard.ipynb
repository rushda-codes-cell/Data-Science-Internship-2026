# %%
import zipfile

zip_path = r"A:\Download\RetailPulse_Day19_20_FIXED.zip"
extract_folder = r"A:\Download\RetailPulse_Day19_20_FIXED"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_folder)
"A:\Download\RetailPulse_Day19_20_FIXED"
print("Extracted successfully!")
# Out:
# Extracted successfully!

# %%
import subprocess

subprocess.Popen(
    [
        "streamlit",
        "run",
        r"A:\Download\RetailPulse_Day19_20_FIXED\app.py"
    ],
    creationflags=subprocess.CREATE_NEW_CONSOLE
)

print("Streamlit started!")
# Out:
# Streamlit started!
