# %%
import pandas as pd
import joblib

# %%
old_data = pd.read_csv("Year_2009_2010_Cleaned.csv")
new_data = pd.read_csv("Year_2010_2011_Cleaned.csv")

print("Old Dataset Shape:", old_data.shape)
print("New Dataset Shape:", new_data.shape)
# Out:
# Old Dataset Shape: (406876, 12)
# New Dataset Shape: (541910, 13)

# %%
print("\nMissing Values")
print(new_data.isnull().sum())

print("\nDataset Information")
new_data.info()
# Out:
# Missing Values
# Invoice                  0
# StockCode                0
# Description           1454
# Quantity                 0
# InvoiceDate              0
# Price                    0
# Customer ID         135080
# Country                  0
# Customer_Segment    541910
# Sales_Channel           41
# Payment_Mode            41
# Order_Priority          41
# Unnamed: 12             41
# dtype: int64
#
# Dataset Information
# <class 'pandas.DataFrame'>
# RangeIndex: 541910 entries, 0 to 541909
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice           541910 non-null  str
#  1   StockCode         541910 non-null  str
#  2   Description       540456 non-null  str
#  3   Quantity          541910 non-null  int64
#  4   InvoiceDate       541910 non-null  str
#  5   Price             541910 non-null  float64
#  6   Customer ID       406830 non-null  float64
# ...

# %%
forecasting_model = True
churn_model = True
inventory_optimization = True
feature_importance = True
drift_detection = True
retraining_pipeline = True

print("Week 2 Progress")

print("Forecasting Model :", forecasting_model)
print("Churn Prediction Model :", churn_model)
print("Inventory Optimization :", inventory_optimization)
print("Feature Importance :", feature_importance)
print("Drift Detection :", drift_detection)
print("Automated Retraining :", retraining_pipeline)
# Out:
# Week 2 Progress
# Forecasting Model : True
# Churn Prediction Model : True
# Inventory Optimization : True
# Feature Importance : True
# Drift Detection : True
# Automated Retraining : True

# %%
if (
    forecasting_model
    and churn_model
    and inventory_optimization
    and feature_importance
    and drift_detection
    and retraining_pipeline
):
    print("Week 2 Checkpoint Completed Successfully!")
else:
    print("Some tasks are still pending.")
# Out:
# Week 2 Checkpoint Completed Successfully!

# %%
summary = {
    "Task": [
        "Forecasting Model",
        "Churn Prediction",
        "Inventory Optimization",
        "Feature Importance",
        "Drift Detection",
        "Automated Retraining"
    ],
    "Status": [
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed",
        "Completed"
    ]
}

summary_df = pd.DataFrame(summary)

summary_df
# Out:
#                      Task     Status
# 0       Forecasting Model  Completed
# 1        Churn Prediction  Completed
# 2  Inventory Optimization  Completed
# 3      Feature Importance  Completed
# 4         Drift Detection  Completed
# 5    Automated Retraining  Completed
